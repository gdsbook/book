# %% [markdown]
# # Spatial Data Processing
#
# Intro paragraph
# * deterministic spatial analysis (SG)
#
# * Explain what we mean by dsa
# * outline what we will cover below
#
#
#  airports.csv

# %% [markdown]
# ## Vignette: Airports

# %% [markdown]
# - Querying based on attributes (volume, lon/lat, etc.)

# %%
import pysal as ps
import pandas as pd
df = pd.read_csv("data/airports/world-airports.csv")

# %%
df.head()
# Out:
#      id ident           type  \
# 0  2434  EGLL  large_airport
# 1  3632  KLAX  large_airport
# 2  3754  KORD  large_airport
# 3  3622  KJFK  large_airport
# 4  3384  KATL  large_airport
#
#                                                name  latitude_deg  \
# 0                           London Heathrow Airport     51.470600
# 1                 Los Angeles International Airport     33.942501
# 2              Chicago O'Hare International Airport     41.978600
# 3              John F Kennedy International Airport     40.639801
# 4  Hartsfield Jackson Atlanta International Airport     33.636700
#
#    longitude_deg  elevation_ft continent iso_country iso_region municipality  \
# 0      -0.461941          83.0        EU          GB     GB-ENG       London
# 1    -118.407997         125.0       NaN          US      US-CA  Los Angeles
# 2     -87.904800         672.0       NaN          US      US-IL      Chicago
# 3     -73.778900          13.0       NaN          US      US-NY     New York
# 4     -84.428101        1026.0       NaN          US      US-GA      Atlanta
#
#    scheduled_service gps_code iata_code local_code  \
# 0                  1     EGLL       LHR        NaN
# 1                  1     KLAX       LAX        LAX
# 2                  1     KORD       ORD        ORD
# 3                  1     KJFK       JFK        JFK
# 4                  1     KATL       ATL        ATL
#
#                                            home_link  \
# 0                    http://www.heathrowairport.com/
# 1                            http://www.iflylax.com/
# 2  http://www.flychicago.com/ohare/en/home/Pages/...
# 3  http://www.panynj.gov/CommutingTravel/airports...
# 4                    http://www.atlanta-airport.com/
#
#                                       wikipedia_link  \
# 0  http://en.wikipedia.org/wiki/London_Heathrow_A...
# 1  http://en.wikipedia.org/wiki/Los_Angeles_Inter...
# 2  http://en.wikipedia.org/wiki/O'Hare_Internatio...
# 3  http://en.wikipedia.org/wiki/John_F._Kennedy_I...
# 4  http://en.wikipedia.org/wiki/Hartsfield-Jackso...
#
#                                   keywords    score               last_updated
# 0                             LON, Londres  1251675  2016-02-09T10:54:31+00:00
# 1                                      NaN  1335475  2010-01-23T11:27:55+00:00
# 2                       CHI, Orchard Place  1503175  2014-08-19T18:55:27+00:00
# 3  Manhattan, New York City, NYC, Idlewild  1052075  2010-01-23T11:27:54+00:00
# 4                                      NaN  2002475  2008-06-13T14:30:04+00:00

# %% [markdown]
# Let's use pandas to query for the airports within the `large_airport` class:

# %%
df[df.type == 'large_airport']
# Out:
#            id    ident           type  \
# 0        2434     EGLL  large_airport
# 1        3632     KLAX  large_airport
# 2        3754     KORD  large_airport
# 3        3622     KJFK  large_airport
# 4        3384     KATL  large_airport
# 5        4185     LFPG  large_airport
# 6        3878     KSFO  large_airport
# 7        2513     EHAM  large_airport
# 8        2212     EDDF  large_airport
# 9        3521     KEWR  large_airport
# 10       3631     KLAS  large_airport
# 11       3488     KDFW  large_airport
# 12       3670     KMCO  large_airport
# 13       3486     KDEN  large_airport
# 14       3685     KMIA  large_airport
# 15       3602     KIAD  large_airport
# 16       3643     KLGA  large_airport
# 17       3772     KPHX  large_airport
# 18       2429     EGKK  large_airport
# 19       3875     KSEA  large_airport
# 20       3422     KBOS  large_airport
# 21       3771     KPHL  large_airport
# 22       1990     CYYZ  large_airport
# 23       3483     KDCA  large_airport
# 24       3604     KIAH  large_airport
# 25       3457     KCLT  large_airport
# 26       3497     KDTW  large_airport
# 27       2218     EDDM  large_airport
# 28       3709     KMSP  large_airport
# 29       4372     LIRF  large_airport
# ...       ...      ...            ...
# 6695     3567     KGSB  large_airport
# 6696     3914     KSZL  large_airport
# 6697     3391     KBAB  large_airport
# 6698     3715     KMUO  large_airport
# 6699     3573     KGUS  large_airport
# 6700     5510     RCBS  large_airport
# 7035     6061     SELT  large_airport
# 10197   42924  RU-0035  large_airport
# 10260  299238     rjns  large_airport
# 10316  320984  GB-0458  large_airport
# 10381  309668     DNAI  large_airport
# 10407   27197     ZGNN  large_airport
# 10418   27195     ZGHA  large_airport
# 10500    4168     LFOA  large_airport
# 10501   35102  RU-2244  large_airport
# 10502   30601  PK-0001  large_airport
# 10503   41136  RU-0016  large_airport
# 10504   35046  RU-4464  large_airport
# 10506   42967     UUBW  large_airport
# 11631   34954     UWKG  large_airport
# 41518  309579     VCRI  large_airport
# 42016  317314  US-0303  large_airport
# 42399  320983  CA-0671  large_airport
# 42571  322136      YYZ  large_airport
# 42689  299747  OM-0004  large_airport
# 43270   44093     ZBNY  large_airport
# 44663  299738  OM-0003  large_airport
# 47391  302303     RKJB  large_airport
# 48343   45229      AMC  large_airport
# 48768  309298  ID-0017  large_airport
#
#                                                     name  latitude_deg  \
# 0                                London Heathrow Airport     51.470600
# 1                      Los Angeles International Airport     33.942501
# 2                   Chicago O'Hare International Airport     41.978600
# 3                   John F Kennedy International Airport     40.639801
# 4       Hartsfield Jackson Atlanta International Airport     33.636700
# 5                Charles de Gaulle International Airport     49.012798
# 6                    San Francisco International Airport     37.618999
# 7                             Amsterdam Airport Schiphol     52.308601
# 8                Frankfurt am Main International Airport     50.033333
# 9                   Newark Liberty International Airport     40.692501
# 10                        McCarran International Airport     36.080101
# 11               Dallas Fort Worth International Airport     32.896801
# 12                         Orlando International Airport     28.429399
# 13                          Denver International Airport     39.861698
# 14                           Miami International Airport     25.793200
# 15               Washington Dulles International Airport     38.944500
# 16                                    La Guardia Airport     40.777199
# 17              Phoenix Sky Harbor International Airport     33.434299
# 18                                London Gatwick Airport     51.148102
# 19                  Seattle Tacoma International Airport     47.449001
# 20     General Edward Lawrence Logan International Ai...     42.364300
# 21                    Philadelphia International Airport     39.871899
# 22               Lester B. Pearson International Airport     43.677200
# 23             Ronald Reagan Washington National Airport     38.852100
# 24          George Bush Intercontinental Houston Airport     29.984400
# 25               Charlotte Douglas International Airport     35.214001
# 26             Detroit Metropolitan Wayne County Airport     42.212399
# 27                          Munich International Airport     48.353802
# 28     Minneapolis-St Paul International/Wold-Chamber...     44.882000
# 29                   Leonardo da Vinci–Fiumicino Airport     41.800278
# ...                                                  ...           ...
# 6695                      Seymour Johnson Air Force Base     35.339401
# 6696                             Whiteman Air Force Base     38.730301
# 6697                                Beale Air Force Base     39.136101
# 6698                        Mountain Home Air Force Base     43.043598
# 6699                            Grissom Air Reserve Base     40.648102
# 6700                                      Kinmen Airport     24.427900
# 7035                      Cotopaxi International Airport     -0.906833
# 10197                               Grozny North Airport     43.388302
# 10260                          Mt. Fuji Shizuoka Airport     34.796043
# 10316                                    [Duplicate] Pic     55.505694
# 10381                    Akwa Ibom International Airport      4.872500
# 10407                               Nanning Wuxu Airport     22.608299
# 10418            Changsha Huanghua International Airport     28.189199
# 10500                            Avord (BA 702) Air Base     47.053299
# 10501                                  Ukrainka Air Base     51.169997
# 10502  (Under construction) New Islamabad Internation...     33.560714
# 10503                                   Lipetsk Air Base     52.634998
# 10504                                    Olenya Air Base     68.151802
# 10506                    Zhukovsky International Airport     55.553299
# 11631                            Borisoglebskoye Airport     55.866699
# 41518            Mattala Rajapaksa International Airport      6.284467
# 42016                                                atl     33.137551
# 42399                                               Cyll     53.310365
# 42571              Toronto Pearson International Airport      0.000000
# 42689                                     Rustaq Airport     23.640556
# 43270                            Beijing Nanyuan Airport     39.782799
# 44663                               Duqm Jaaluni Airport     19.500000
# 47391                         Muan International Airport     34.991406
# 48343                Mar de Cortés International Airport     31.351621
# 48768                Sungai Siring International Airport     -0.373611
#
#        longitude_deg  elevation_ft continent iso_country iso_region  \
# 0          -0.461941          83.0        EU          GB     GB-ENG
# 1        -118.407997         125.0       NaN          US      US-CA
# 2         -87.904800         672.0       NaN          US      US-IL
# 3         -73.778900          13.0       NaN          US      US-NY
# 4         -84.428101        1026.0       NaN          US      US-GA
# 5           2.550000         392.0        EU          FR       FR-J
# 6        -122.375000          13.0       NaN          US      US-CA
# 7           4.763890         -11.0        EU          NL      NL-NH
# 8           8.570556         364.0        EU          DE      DE-HE
# 9         -74.168701          18.0       NaN          US      US-NJ
# 10       -115.152000        2181.0       NaN          US      US-NV
# 11        -97.038002         607.0       NaN          US      US-TX
# 12        -81.308998          96.0       NaN          US      US-FL
# 13       -104.672997        5431.0       NaN          US      US-CO
# 14        -80.290604           8.0       NaN          US      US-FL
# 15        -77.455803         312.0       NaN          US      US-DC
# 16        -73.872597          21.0       NaN          US      US-NY
# 17       -112.012001        1135.0       NaN          US      US-AZ
# 18         -0.190278         202.0        EU          GB     GB-ENG
# 19       -122.308998         433.0       NaN          US      US-WA
# 20        -71.005203          20.0       NaN          US      US-MA
# 21        -75.241096          36.0       NaN          US      US-PA
# 22        -79.630600         569.0       NaN          CA      CA-ON
# 23        -77.037697          15.0       NaN          US      US-DC
# 24        -95.341400          97.0       NaN          US      US-TX
# 25        -80.943100         748.0       NaN          US      US-NC
# 26        -83.353401         645.0       NaN          US      US-MI
# 27         11.786100        1487.0        EU          DE      DE-BY
# 28        -93.221802         841.0       NaN          US      US-MN
# 29         12.238889          13.0        EU          IT      IT-62
# ...              ...           ...       ...         ...        ...
# 6695      -77.960602         109.0       NaN          US      US-NC
# 6696      -93.547897         870.0       NaN          US      US-MO
# 6697     -121.436996         113.0       NaN          US      US-CA
# 6698     -115.872002        2996.0       NaN          US      US-ID
# 6699      -86.152100         812.0       NaN          US      US-IN
# 6700      118.359001          93.0        AS          TW    TW-X-KM
# 7035      -78.615799        9205.0        SA          EC       EC-X
# 10197      45.698601         548.0        EU          RU      RU-CE
# 10260     138.187752         433.0        AS          JP      JP-22
# 10316      -4.586792           NaN        EU          GB     GB-SCT
# 10381       8.093000         170.0        AF          NG      NG-AK
# 10407     108.171997         421.0        AS          CN      CN-45
# 10418     113.220001         217.0        AS          CN      CN-43
# 10500       2.632500         580.0        EU          FR       FR-F
# 10501     128.445007         771.0        EU          RU     RU-AMU
# 10502      72.851614         646.0        AS          PK      PK-PB
# 10503      39.445000         636.0        EU          RU     RU-LIP
# 10504      33.463902         702.0        EU          RU     RU-MUR
# 10506      38.150002         377.0        EU          RU     RU-MOS
# 11631      49.133301         213.0        EU          RU      RU-TA
# 41518      81.124128         157.0        AS          LK       LK-3
# 42016     -84.375000           NaN       NaN          US     US-U-A
# 42399    -110.072021           NaN       NaN          CA     CA-U-A
# 42571       0.000000           NaN       NaN          CA      CA-ON
# 42689      57.487500         349.0        AS          OM      OM-BA
# 43270     116.388000           NaN        AS          CN      CN-11
# 44663      57.642800         380.0        AS          OM      OM-WU
# 47391     126.382814          35.0        AS          KR      KR-46
# 48343    -113.305864          71.0       NaN          MX     MX-SON
# 48768     117.255556          82.0        AS          ID      ID-KI
#
#                municipality  scheduled_service gps_code iata_code local_code  \
# 0                    London                  1     EGLL       LHR        NaN
# 1               Los Angeles                  1     KLAX       LAX        LAX
# 2                   Chicago                  1     KORD       ORD        ORD
# 3                  New York                  1     KJFK       JFK        JFK
# 4                   Atlanta                  1     KATL       ATL        ATL
# 5                     Paris                  1     LFPG       CDG        NaN
# 6             San Francisco                  1     KSFO       SFO        SFO
# 7                 Amsterdam                  1     EHAM       AMS        NaN
# 8         Frankfurt-am-Main                  1     EDDF       FRA        NaN
# 9                    Newark                  1     KEWR       EWR        EWR
# 10                Las Vegas                  1     KLAS       LAS        LAS
# 11        Dallas-Fort Worth                  1     KDFW       DFW        DFW
# 12                  Orlando                  1     KMCO       MCO        MCO
# 13                   Denver                  1     KDEN       DEN        DEN
# 14                    Miami                  1     KMIA       MIA        MIA
# 15               Washington                  1     KIAD       IAD        IAD
# 16                 New York                  1     KLGA       LGA        LGA
# 17                  Phoenix                  1     KPHX       PHX        PHX
# 18                   London                  1     EGKK       LGW        NaN
# 19                  Seattle                  1     KSEA       SEA        SEA
# 20                   Boston                  1     KBOS       BOS        BOS
# 21             Philadelphia                  1     KPHL       PHL        PHL
# 22                  Toronto                  1     CYYZ       YYZ        YYZ
# 23               Washington                  1     KDCA       DCA        DCA
# 24                  Houston                  1     KIAH       IAH        IAH
# 25                Charlotte                  1     KCLT       CLT        CLT
# 26                  Detroit                  1     KDTW       DTW        DTW
# 27                   Munich                  1     EDDM       MUC        NaN
# 28              Minneapolis                  1     KMSP       MSP        MSP
# 29                     Rome                  1     LIRF       FCO       RM11
# ...                     ...                ...      ...       ...        ...
# 6695              Goldsboro                  0     KGSB       GSB        GSB
# 6696            Knob Noster                  0     KSZL       SZL        SZL
# 6697             Marysville                  0     KBAB       BAB        BAB
# 6698          Mountain Home                  0     KMUO       MUO        MUO
# 6699                   Peru                  0     KGUS       GUS        GUS
# 6700                Shang-I                  1     RCBS       KNH        NaN
# 7035              Latacunga                  1     SELT       LTX        NaN
# 10197                Grozny                  1     URMG       GRV        NaN
# 10260  Makinohara / Shimada                  1     RJNS       FSZ        NaN
# 10316             Prestwick                  0      NaN       NaN        NaN
# 10381                   Uyo                  1     DNAI       QUO        NaN
# 10407               Nanning                  1     ZGNN       NNG        NaN
# 10418              Changsha                  1     ZGHA       CSX        NaN
# 10500                 Avord                  0     LFOA       NaN        NaN
# 10501             Belogorsk                  0      NaN       NaN       XHBU
# 10502             Islamabad                  0      NaN       NaN        NaN
# 10503               Lipetsk                  0      NaN       NaN        NaN
# 10504            Olenegorsk                  0      NaN       NaN       XLMO
# 10506             Zhukovsky                  1     UUBW       ZIA        NaN
# 11631                 Kazan                  0     UWKG       NaN        NaN
# 41518                   NaN                  1     VCRI       HRI       VCRI
# 42016                   NaN                  1      NaN       NaN        NaN
# 42399                   NaN                  1      NaN       NaN        NaN
# 42571                   NaN                  1      NaN       YYZ        NaN
# 42689           Al Masna'ah                  0     OORQ       MNH        NaN
# 43270               Beijing                  1     ZBNY       NAY        NaN
# 44663                  Duqm                  1     OODQ       JNJ        NaN
# 47391                  Muan                  1     RKJB       MWX        NaN
# 48343        Puerto Peñasco                  1     MMPE       PPE        NaN
# 48768             Samarinda                  1      NaN       NaN        NaN
#
#                                                home_link  \
# 0                        http://www.heathrowairport.com/
# 1                                http://www.iflylax.com/
# 2      http://www.flychicago.com/ohare/en/home/Pages/...
# 3      http://www.panynj.gov/CommutingTravel/airports...
# 4                        http://www.atlanta-airport.com/
# 5                        http://www.aeroportsdeparis.fr/
# 6                                 http://www.flysfo.com/
# 7                                http://www.schiphol.nl/
# 8                       http://www.frankfurt-airport.de/
# 9      http://www.panynj.gov/CommutingTravel/airports...
# 10                              http://www.mccarran.com/
# 11                            http://www.dfwairport.com/
# 12                       http://www.orlandoairports.net/
# 13                             http://www.flydenver.com/
# 14                         http://www.miami-airport.com/
# 15                           http://www.mwaa.com/dulles/
# 16     http://www.panynj.gov/CommutingTravel/airports...
# 17                  http://phoenix.gov/skyharborairport/
# 18                        http://www.gatwickairport.com/
# 19                    http://www.portseattle.org/seatac/
# 20                        http://www.massport.com/logan/
# 21                                   http://www.phl.org/
# 22                                  http://www.gtaa.com/
# 23     http://www.flyreagan.com/dca/reagan-national-a...
# 24                        http://www.fly2houston.com/iah
# 25                      http://www.charlotteairport.com/
# 26                          http://www.metroairport.com/
# 27                        http://www.munich-airport.com/
# 28                            http://www.mspairport.com/
# 29     http://www.adr.it/portal/portal/adr/Fiumicino/...
# ...                                                  ...
# 6695                   http://www.seymourjohnson.af.mil/
# 6696                         http://www.whiteman.af.mil/
# 6697                                                 NaN
# 6698                     http://www.mountainhome.af.mil/
# 6699                     http://www.grissom.afrc.af.mil/
# 6700                   http://www.kma.gov.tw/index-e.htm
# 7035                   http://www.dgac.gob.ec/latacunga/
# 10197                                                NaN
# 10260  http://www.mtfuji-shizuokaairport.jp/english/i...
# 10316                                                NaN
# 10381                     http://www.ibomairport.com.ng/
# 10407                          http://www.nnairport.com/
# 10418                                                NaN
# 10500                                                NaN
# 10501                                                NaN
# 10502                            http://www.niia.com.pk/
# 10503                                                NaN
# 10504                                                NaN
# 10506                                   http://zia.aero/
# 11631                                                NaN
# 41518                                http://www.mria.lk/
# 42016                                                NaN
# 42399                                                NaN
# 42571                                                NaN
# 42689                                                NaN
# 43270                                                NaN
# 44663                       http://www.omanairports.com/
# 47391            http://muan.airport.co.kr/doc/muan_eng/
# 48343                                                NaN
# 48768     http://www.proyek.dishubprovkaltim.info/?pro=1
#
#                                           wikipedia_link  \
# 0      http://en.wikipedia.org/wiki/London_Heathrow_A...
# 1      http://en.wikipedia.org/wiki/Los_Angeles_Inter...
# 2      http://en.wikipedia.org/wiki/O'Hare_Internatio...
# 3      http://en.wikipedia.org/wiki/John_F._Kennedy_I...
# 4      http://en.wikipedia.org/wiki/Hartsfield-Jackso...
# 5      http://en.wikipedia.org/wiki/Charles_de_Gaulle...
# 6      http://en.wikipedia.org/wiki/San_Francisco_Int...
# 7      http://en.wikipedia.org/wiki/Amsterdam_Schipho...
# 8         http://en.wikipedia.org/wiki/Frankfurt_Airport
# 9      http://en.wikipedia.org/wiki/Newark_Liberty_In...
# 10     http://en.wikipedia.org/wiki/McCarran_Internat...
# 11     http://en.wikipedia.org/wiki/Dallas-Fort_Worth...
# 12     http://en.wikipedia.org/wiki/Orlando_Internati...
# 13     http://en.wikipedia.org/wiki/Denver_Internatio...
# 14     http://en.wikipedia.org/wiki/Miami_Internation...
# 15     http://en.wikipedia.org/wiki/Washington_Dulles...
# 16        http://en.wikipedia.org/wiki/LaGuardia_Airport
# 17     http://en.wikipedia.org/wiki/Phoenix_Sky_Harbo...
# 18     http://en.wikipedia.org/wiki/London_Gatwick_Ai...
# 19     http://en.wikipedia.org/wiki/Seattle-Tacoma_In...
# 20     http://en.wikipedia.org/wiki/Logan_Internation...
# 21     http://en.wikipedia.org/wiki/Philadelphia_Inte...
# 22     http://en.wikipedia.org/wiki/Toronto_Pearson_I...
# 23     http://en.wikipedia.org/wiki/Ronald_Reagan_Was...
# 24     http://en.wikipedia.org/wiki/George_Bush_Inter...
# 25     http://en.wikipedia.org/wiki/Charlotte/Douglas...
# 26     http://en.wikipedia.org/wiki/Detroit_Metropoli...
# 27     http://en.wikipedia.org/wiki/Munich_Internatio...
# 28     http://en.wikipedia.org/wiki/Minneapolis-Saint...
# 29     http://en.wikipedia.org/wiki/Leonardo_da_Vinci...
# ...                                                  ...
# 6695   http://en.wikipedia.org/wiki/Seymour_Johnson_A...
# 6696   http://en.wikipedia.org/wiki/Whiteman_Air_Forc...
# 6697   http://en.wikipedia.org/wiki/Beale_Air_Force_Base
# 6698   https://en.wikipedia.org/wiki/Mountain_Home_Ai...
# 6699   http://en.wikipedia.org/wiki/Grissom_Air_Reser...
# 6700         http://en.wikipedia.org/wiki/Kinmen_Airport
# 7035   http://es.wikipedia.org/wiki/Aeropuerto_Intern...
# 10197       https://en.wikipedia.org/wiki/Grozny_Airport
# 10260      http://en.wikipedia.org/wiki/Shizuoka_Airport
# 10316                                                NaN
# 10381     http://en.wikipedia.org/wiki/Akwa_Ibom_Airport
# 10407  http://en.wikipedia.org/wiki/Nanning_Wuxu_Inte...
# 10418  http://en.wikipedia.org/wiki/Changsha_Huanghua...
# 10500       https://en.wikipedia.org/wiki/Avord_Air_Base
# 10501   http://en.wikipedia.org/wiki/Ukrainka_(air_base)
# 10502  http://en.wikipedia.org/wiki/New_Islamabad_Int...
# 10503      http://en.wikipedia.org/wiki/Lipetsk_Air_Base
# 10504     http://en.wikipedia.org/wiki/Olenya_(air_base)
# 10506  https://en.wikipedia.org/wiki/Zhukovsky_Intern...
# 11631  http://en.wikipedia.org/wiki/Borisoglebskoye_A...
# 41518  http://en.wikipedia.org/wiki/Mattala_Rajapaksa...
# 42016                                                NaN
# 42399                                                NaN
# 42571                                                NaN
# 42689       https://en.wikipedia.org/wiki/Rustaq_Airport
# 43270       http://en.wikipedia.org/wiki/Nanyuan_Airport
# 44663  https://en.wikipedia.org/wiki/Duqm_Jaaluni_Air...
# 47391  http://en.wikipedia.org/wiki/Muan_Internationa...
# 48343  http://en.wikipedia.org/wiki/Mar_de_Cort%C3%A9...
# 48768  http://en.wikipedia.org/wiki/Samarinda_Interna...
#
#                                                 keywords    score  \
# 0                                           LON, Londres  1251675
# 1                                                    NaN  1335475
# 2                                     CHI, Orchard Place  1503175
# 3                Manhattan, New York City, NYC, Idlewild  1052075
# 4                                                    NaN  2002475
# 5      PAR, Aéroport Roissy-Charles de Gaulle, Roissy...  1127475
# 6                                               QSF, QBA  1112475
# 7                                                    NaN  1093275
# 8                              EDAF, Rhein-Main Air Base  1144675
# 9                          Manhattan, New York City, NYC  1064475
# 10                                                   NaN  1068475
# 11                                                   QDF  1203175
# 12                             Disney World,Epcot Center  1044075
# 13                                             DVX, KVDX  1103275
# 14                                    MFW, South Florida  1073075
# 15                                                   WAS  1023875
# 16     Manhattan, New York City, NYC, Glenn H. Curtis...  1030575
# 17                                                   NaN  1060875
# 18                               LON, Crawley, Charlwood  1049275
# 19                                                   NaN  1038675
# 20     General Edward Lawrence Logan International Ai...  1035875
# 21                                                   NaN  1031075
# 22            YTO, Toronto International Airport, Malton  1040275
# 23                                                   WAS  1016175
# 24                                                   QHO  1055675
# 25                                                   NaN  1028075
# 26                            DTT, Detroit Metro Airport  1079375
# 27     Franz Josef Strauss International Airport, Flu...  1026675
# 28                                                   NaN  1085275
# 29        ROM, Rome Fiumicino Airport, Fiumicino Airport  1031875
# ...                                                  ...      ...
# 6695                                                 NaN      850
# 6696                                 Sedalia Glider Base      850
# 6697                                                 NaN      850
# 6698                                                 NaN      850
# 6699                                                 NaN      850
# 6700   Shang Yi Airport, 金門尚義機場, 金门尚义机场, Jīnmén Shàng...      850
# 7035   Latacunga, Vulcano, Ecuador, Cargo, Long runwa...      400
# 10197  Grozny Severny, Grozny, Аэропорт Грозный Север...        0
# 10260                                                NaN        0
# 10316                                                NaN        0
# 10381                                                NaN        0
# 10407                      南宁吴圩机场, Nanning Wuxu Air Base     1200
# 10418                                           长沙黄花国际机场     1050
# 10500                                                NaN      850
# 10501                                     ЬХБУ, Украинка      850
# 10502                                         Fateh Jang      850
# 10503                                                NaN      850
# 10504                           ЬЛМО, Оленья, Olenegorsk      850
# 10506  Аэропорт Раменское, Zhukovsky Air Base, Gromov...      850
# 11631                            Аэропорт Борисоглебское      250
# 41518                   Hambantota International Airport        0
# 42016                                                NaN        0
# 42399                                                NaN        0
# 42571                                                NaN        0
# 42689               Musanaa, Wadi al Maawil, Al Muladdah        0
# 43270                                                NaN        0
# 44663                                                NaN        0
# 47391                                     Gwangju, Mokpo        0
# 48343                                                NaN        0
# 48768              Sungai Siring Airport, فرودگاه سیرینگ        0
#
#                     last_updated
# 0      2016-02-09T10:54:31+00:00
# 1      2010-01-23T11:27:55+00:00
# 2      2014-08-19T18:55:27+00:00
# 3      2010-01-23T11:27:54+00:00
# 4      2008-06-13T14:30:04+00:00
# 5      2010-01-05T18:17:43+00:00
# 6      2008-06-13T14:30:04+00:00
# 7      2011-10-05T23:26:15+00:00
# 8      2016-09-15T03:34:21+00:00
# 9      2008-06-13T14:30:04+00:00
# 10     2010-07-05T16:48:39+00:00
# 11     2008-06-13T14:30:04+00:00
# 12     2008-06-13T14:30:04+00:00
# 13     2015-11-13T09:28:42+00:00
# 14     2008-06-13T14:30:04+00:00
# 15     2010-01-23T11:27:53+00:00
# 16     2010-01-23T11:27:55+00:00
# 17     2008-06-13T14:30:04+00:00
# 18     2009-01-30T17:53:54+00:00
# 19     2008-06-13T14:30:04+00:00
# 20     2010-01-23T11:27:48+00:00
# 21     2008-06-13T14:30:04+00:00
# 22     2009-10-15T13:44:39+00:00
# 23     2016-12-13T09:13:00+00:00
# 24     2008-06-13T14:30:04+00:00
# 25     2009-01-30T14:52:52+00:00
# 26     2008-06-13T14:30:04+00:00
# 27     2015-10-17T03:56:24+00:00
# 28     2009-12-17T08:53:11+00:00
# 29     2016-10-08T00:37:02+00:00
# ...                          ...
# 6695   2014-10-04T01:51:25+00:00
# 6696   2015-05-31T03:54:50+00:00
# 6697   2012-06-21T01:43:23+00:00
# 6698   2016-05-31T09:36:32+00:00
# 6699   2014-10-03T23:32:05+00:00
# 6700   2009-07-11T09:13:57+00:00
# 7035   2013-02-25T10:27:48+00:00
# 10197  2016-05-31T10:29:00+00:00
# 10260  2013-09-29T13:51:58+00:00
# 10316  2016-11-12T08:02:29+00:00
# 10381  2013-09-28T12:53:18+00:00
# 10407  2009-04-16T20:31:13+00:00
# 10418  2013-05-17T01:38:00+00:00
# 10500  2016-05-31T09:37:29+00:00
# 10501  2017-01-20T18:03:03+00:00
# 10502  2010-12-28T15:14:35+00:00
# 10503  2008-08-11T13:10:57+00:00
# 10504  2015-09-25T10:50:57+00:00
# 10506  2016-10-05T13:48:10+00:00
# 11631  2015-08-21T19:49:50+00:00
# 41518  2015-10-06T05:20:29+00:00
# 42016  2016-03-19T09:20:40+00:00
# 42399  2016-10-31T22:20:17+00:00
# 42571  2017-02-12T14:34:35+00:00
# 42689  2016-03-16T00:34:25+00:00
# 43270  2009-08-30T19:53:52+00:00
# 44663  2016-05-31T09:45:53+00:00
# 47391  2015-08-19T02:40:29+00:00
# 48343  2016-05-31T10:21:05+00:00
# 48768  2015-02-15T02:52:02+00:00
#
# [574 rows x 20 columns]

# %% [markdown]
# Since both latitude and longitude are columns in the dataframe we can use pandas to carry out a limited number of geospatial queries. For example, extract all the airports in the northern hemisphere:

# %%
df[df.latitude_deg > 0.0]
# Out:
#            id    ident            type  \
# 0        2434     EGLL   large_airport
# 1        3632     KLAX   large_airport
# 2        3754     KORD   large_airport
# 3        3622     KJFK   large_airport
# 4        3384     KATL   large_airport
# 5        4185     LFPG   large_airport
# 6        3878     KSFO   large_airport
# 7        2513     EHAM   large_airport
# 8        2212     EDDF   large_airport
# 9        3521     KEWR   large_airport
# 10       3631     KLAS   large_airport
# 11       3488     KDFW   large_airport
# 12       3670     KMCO   large_airport
# 13       3486     KDEN   large_airport
# 14       3685     KMIA   large_airport
# 15       3602     KIAD   large_airport
# 16       3643     KLGA   large_airport
# 17       3772     KPHX   large_airport
# 18       2429     EGKK   large_airport
# 19       3875     KSEA   large_airport
# 20       3422     KBOS   large_airport
# 21       3771     KPHL   large_airport
# 22       1990     CYYZ   large_airport
# 23       3483     KDCA   large_airport
# 24       3604     KIAH   large_airport
# 25       3457     KCLT   large_airport
# 26       3497     KDTW   large_airport
# 27       2218     EDDM   large_airport
# 28       3709     KMSP   large_airport
# 29       4372     LIRF   large_airport
# ...       ...      ...             ...
# 50599   44389  KZ-0071          closed
# 50600   44390  KZ-0072          closed
# 50601  319812      HSJ   small_airport
# 50602   43684     UWKV  medium_airport
# 50603  308462     ZLZW  medium_airport
# 50604   44386  KZ-0070   small_airport
# 50605   46369  UA-0071          closed
# 50606   46370  UA-0072          closed
# 50607   44432     UKKO  medium_airport
# 50608  308157  DE-0040   small_airport
# 50609   44743  RU-0197   small_airport
# 50610  319653  MX-0257   small_airport
# 50611   43961  CZ-0044        heliport
# 50612   46129  RU-0304  medium_airport
# 50613  319421  IT-0275   small_airport
# 50614   45182  UA-0053          closed
# 50615  319121  MX-0184        heliport
# 50616   43747     EBZO        heliport
# 50618   43230  GE-0002          closed
# 50620  298761  IT-0032   small_airport
# 50621  308403     ZUZY  medium_airport
# 50622  316165     LDZE   small_airport
# 50623   44702  RU-0193        heliport
# 50624   43804     LOKZ        heliport
# 50625   43816     LOAZ        heliport
# 50626   43708  NL-0013        heliport
# 50627  315523  RU-0438   small_airport
# 50628  318187  KZ-0081   small_airport
# 50629   42246     BITH          closed
# 50630  315917  BG-0027   small_airport
#
#                                                     name  latitude_deg  \
# 0                                London Heathrow Airport     51.470600
# 1                      Los Angeles International Airport     33.942501
# 2                   Chicago O'Hare International Airport     41.978600
# 3                   John F Kennedy International Airport     40.639801
# 4       Hartsfield Jackson Atlanta International Airport     33.636700
# 5                Charles de Gaulle International Airport     49.012798
# 6                    San Francisco International Airport     37.618999
# 7                             Amsterdam Airport Schiphol     52.308601
# 8                Frankfurt am Main International Airport     50.033333
# 9                   Newark Liberty International Airport     40.692501
# 10                        McCarran International Airport     36.080101
# 11               Dallas Fort Worth International Airport     32.896801
# 12                         Orlando International Airport     28.429399
# 13                          Denver International Airport     39.861698
# 14                           Miami International Airport     25.793200
# 15               Washington Dulles International Airport     38.944500
# 16                                    La Guardia Airport     40.777199
# 17              Phoenix Sky Harbor International Airport     33.434299
# 18                                London Gatwick Airport     51.148102
# 19                  Seattle Tacoma International Airport     47.449001
# 20     General Edward Lawrence Logan International Ai...     42.364300
# 21                    Philadelphia International Airport     39.871899
# 22               Lester B. Pearson International Airport     43.677200
# 23             Ronald Reagan Washington National Airport     38.852100
# 24          George Bush Intercontinental Houston Airport     29.984400
# 25               Charlotte Douglas International Airport     35.214001
# 26             Detroit Metropolitan Wayne County Airport     42.212399
# 27                          Munich International Airport     48.353802
# 28     Minneapolis-St Paul International/Wold-Chamber...     44.882000
# 29                   Leonardo da Vinci–Fiumicino Airport     41.800278
# ...                                                  ...           ...
# 50599                                     Karas Air Base     48.737000
# 50600                                     Karas Air Base     48.737000
# 50601                                   Shangjie Airport     34.842153
# 50602                                   Zhigansk Airport     66.796501
# 50603                          Zhongwei Shapotou Airport     37.573125
# 50604                                    Zhosaly Airport     45.514999
# 50605                               Zhovti Vody Airstrip     48.350503
# 50606                             Volodimirivka Airstrip     48.284035
# 50607                                    Ozerne Air Base     50.158298
# 50608                                Zierenberg Airfield     51.367000
# 50609                                 Zimovniki Air Base     47.141998
# 50610                                 El Pinocho Airport     19.476550
# 50611                            Bat’A Hospital Heliport     49.226147
# 50612                              Kapustin Yar Airfield     48.667000
# 50613                           Campo di Volo Arcobaleno     44.496944
# 50614                                   Palmira Airfield     49.763000
# 50615                         Jupiter I Platform Helipad     19.520472
# 50616                                Zandvoorde heliport     50.817280
# 50618                                    Zugdidi Airport     42.489201
# 50620                             Campo di Volo Il Grifo     38.637255
# 50621                              Zunyi Xinzhou Airport     27.589500
# 50622                                           Zvekovac     45.823056
# 50623                                  Pushkino Heliport     56.042000
# 50624                                  Zwatzhof Heliport     46.975555
# 50625                                    Zwettl Heliport     48.599998
# 50626           Isala Klinieken. Locatie Sophia Heliport     52.513874
# 50627                              Zyryanka West Airport     65.736700
# 50628                                    Zubovsk Airport     49.800103
# 50629                                   Sauðanes Airport     66.250603
# 50630                                            Gabrovo     42.948200
#
#        longitude_deg  elevation_ft continent iso_country iso_region  \
# 0          -0.461941          83.0        EU          GB     GB-ENG
# 1        -118.407997         125.0       NaN          US      US-CA
# 2         -87.904800         672.0       NaN          US      US-IL
# 3         -73.778900          13.0       NaN          US      US-NY
# 4         -84.428101        1026.0       NaN          US      US-GA
# 5           2.550000         392.0        EU          FR       FR-J
# 6        -122.375000          13.0       NaN          US      US-CA
# 7           4.763890         -11.0        EU          NL      NL-NH
# 8           8.570556         364.0        EU          DE      DE-HE
# 9         -74.168701          18.0       NaN          US      US-NJ
# 10       -115.152000        2181.0       NaN          US      US-NV
# 11        -97.038002         607.0       NaN          US      US-TX
# 12        -81.308998          96.0       NaN          US      US-FL
# 13       -104.672997        5431.0       NaN          US      US-CO
# 14        -80.290604           8.0       NaN          US      US-FL
# 15        -77.455803         312.0       NaN          US      US-DC
# 16        -73.872597          21.0       NaN          US      US-NY
# 17       -112.012001        1135.0       NaN          US      US-AZ
# 18         -0.190278         202.0        EU          GB     GB-ENG
# 19       -122.308998         433.0       NaN          US      US-WA
# 20        -71.005203          20.0       NaN          US      US-MA
# 21        -75.241096          36.0       NaN          US      US-PA
# 22        -79.630600         569.0       NaN          CA      CA-ON
# 23        -77.037697          15.0       NaN          US      US-DC
# 24        -95.341400          97.0       NaN          US      US-TX
# 25        -80.943100         748.0       NaN          US      US-NC
# 26        -83.353401         645.0       NaN          US      US-MI
# 27         11.786100        1487.0        EU          DE      DE-BY
# 28        -93.221802         841.0       NaN          US      US-MN
# 29         12.238889          13.0        EU          IT      IT-62
# ...              ...           ...       ...         ...        ...
# 50599      58.042000           NaN        AS          KZ     KZ-AKT
# 50600      58.042000           NaN        AS          KZ     KZ-AKT
# 50601     113.273983         450.0        AS          CN      CN-41
# 50602     123.361000         292.0        AS          RU      RU-SA
# 50603     105.154454        8202.0        AS          CN      CN-64
# 50604      64.084999         335.0        AS          KZ     KZ-KZY
# 50605      33.444271           NaN        EU          UA      UA-12
# 50606      33.448949           NaN        EU          UA      UA-12
# 50607      28.738300         761.0        EU          UA      UA-18
# 50608       9.336000        1450.0        EU          DE      DE-HE
# 50609      42.395000           NaN        EU          RU     RU-ROS
# 50610    -100.433200        6265.0       NaN          MX     MX-MIC
# 50611      17.705345         738.0        EU          CZ      CZ-ZL
# 50612      45.732000           NaN        EU          RU     RU-AST
# 50613      11.243611           NaN        EU          IT      IT-45
# 50614      32.123000           NaN        EU          UA      UA-71
# 50615     -92.184506          50.0       NaN          MX     MX-CAM
# 50616       2.974564         102.0        EU          BE     BE-VWV
# 50618      41.818699           NaN        AS          GE      GE-SZ
# 50620      15.947750         630.0        EU          IT      IT-78
# 50621     107.000700        2920.0        AS          CN      CN-52
# 50622      16.500000         374.0        EU          HR      HR-01
# 50623      37.978001           NaN        EU          RU     RU-MOS
# 50624      14.274722        2500.0        EU          AT       AT-2
# 50625      15.164167        1900.0        EU          AT       AT-3
# 50626       6.128000           6.0        EU          NL      NL-OV
# 50627     150.705000         150.0        EU          RU      RU-SA
# 50628      84.214661           NaN        AS          KZ     KZ-VOS
# 50629     -15.267200          15.0        EU          IS       IS-6
# 50630      25.359980           NaN        EU          BG      BG-07
#
#             municipality  scheduled_service gps_code iata_code local_code  \
# 0                 London                  1     EGLL       LHR        NaN
# 1            Los Angeles                  1     KLAX       LAX        LAX
# 2                Chicago                  1     KORD       ORD        ORD
# 3               New York                  1     KJFK       JFK        JFK
# 4                Atlanta                  1     KATL       ATL        ATL
# 5                  Paris                  1     LFPG       CDG        NaN
# 6          San Francisco                  1     KSFO       SFO        SFO
# 7              Amsterdam                  1     EHAM       AMS        NaN
# 8      Frankfurt-am-Main                  1     EDDF       FRA        NaN
# 9                 Newark                  1     KEWR       EWR        EWR
# 10             Las Vegas                  1     KLAS       LAS        LAS
# 11     Dallas-Fort Worth                  1     KDFW       DFW        DFW
# 12               Orlando                  1     KMCO       MCO        MCO
# 13                Denver                  1     KDEN       DEN        DEN
# 14                 Miami                  1     KMIA       MIA        MIA
# 15            Washington                  1     KIAD       IAD        IAD
# 16              New York                  1     KLGA       LGA        LGA
# 17               Phoenix                  1     KPHX       PHX        PHX
# 18                London                  1     EGKK       LGW        NaN
# 19               Seattle                  1     KSEA       SEA        SEA
# 20                Boston                  1     KBOS       BOS        BOS
# 21          Philadelphia                  1     KPHL       PHL        PHL
# 22               Toronto                  1     CYYZ       YYZ        YYZ
# 23            Washington                  1     KDCA       DCA        DCA
# 24               Houston                  1     KIAH       IAH        IAH
# 25             Charlotte                  1     KCLT       CLT        CLT
# 26               Detroit                  1     KDTW       DTW        DTW
# 27                Munich                  1     EDDM       MUC        NaN
# 28           Minneapolis                  1     KMSP       MSP        MSP
# 29                  Rome                  1     LIRF       FCO       RM11
# ...                  ...                ...      ...       ...        ...
# 50599               Zhem                  0      NaN       NaN        NaN
# 50600               Zhem                  0      NaN       NaN        NaN
# 50601          Zhengzhou                  0      NaN       HSJ        NaN
# 50602           Zhigansk                  1     UEVV       ZIX        NaN
# 50603           Zhongwei                  1     ZLZW       ZHY        NaN
# 50604            Zhosaly                  0      NaN       NaN        NaN
# 50605        Zhovti Vody                  0      NaN       NaN        NaN
# 50606        Zhovti Vody                  0      NaN       NaN        NaN
# 50607           Zhytomyr                  0     UKKO       NaN        NaN
# 50608         Zierenberg                  0      NaN       NaN        NaN
# 50609          Zimovniki                  0      NaN       NaN        NaN
# 50610          Zitácuaro                  0      NaN       NaN        PIO
# 50611               Zlín                  0      NaN       NaN        NaN
# 50612           Znamensk                  0      NaN       NaN        NaN
# 50613  Zola Predosa (BO)                  0      NaN       NaN       BO11
# 50614        Zolotonosha                  0      NaN       NaN        NaN
# 50615  Zonda De Campeche                  0      NaN       NaN        HJU
# 50616          Zonnebeke                  0     EBZO       NaN        NaN
# 50618            Zugdidi                  0      NaN       NaN        NaN
# 50620             Zungri                  0      NaN       NaN      VVZUN
# 50621              Zunyi                  1     ZUZY       ZYI        NaN
# 50622           Zvekovac                  0     LDZE       NaN        NaN
# 50623       Zverosovkhoz                  0      NaN       NaN        NaN
# 50624           Zwatzhof                  0      NaN       NaN        NaN
# 50625             Zwettl                  0      NaN       NaN        NaN
# 50626             Zwolle                  0      NaN       NaN        NaN
# 50627           Zyryanka                  0      NaN       NaN        NaN
# 50628         Zyryanovsk                  0      NaN       NaN        NaN
# 50629           Þórshöfn                  0     BITH       NaN        NaN
# 50630            Габрово                  0      NaN       NaN        NaN
#
#                                                home_link  \
# 0                        http://www.heathrowairport.com/
# 1                                http://www.iflylax.com/
# 2      http://www.flychicago.com/ohare/en/home/Pages/...
# 3      http://www.panynj.gov/CommutingTravel/airports...
# 4                        http://www.atlanta-airport.com/
# 5                        http://www.aeroportsdeparis.fr/
# 6                                 http://www.flysfo.com/
# 7                                http://www.schiphol.nl/
# 8                       http://www.frankfurt-airport.de/
# 9      http://www.panynj.gov/CommutingTravel/airports...
# 10                              http://www.mccarran.com/
# 11                            http://www.dfwairport.com/
# 12                       http://www.orlandoairports.net/
# 13                             http://www.flydenver.com/
# 14                         http://www.miami-airport.com/
# 15                           http://www.mwaa.com/dulles/
# 16     http://www.panynj.gov/CommutingTravel/airports...
# 17                  http://phoenix.gov/skyharborairport/
# 18                        http://www.gatwickairport.com/
# 19                    http://www.portseattle.org/seatac/
# 20                        http://www.massport.com/logan/
# 21                                   http://www.phl.org/
# 22                                  http://www.gtaa.com/
# 23     http://www.flyreagan.com/dca/reagan-national-a...
# 24                        http://www.fly2houston.com/iah
# 25                      http://www.charlotteairport.com/
# 26                          http://www.metroairport.com/
# 27                        http://www.munich-airport.com/
# 28                            http://www.mspairport.com/
# 29     http://www.adr.it/portal/portal/adr/Fiumicino/...
# ...                                                  ...
# 50599                                                NaN
# 50600                                                NaN
# 50601                                                NaN
# 50602                                                NaN
# 50603                                                NaN
# 50604                                                NaN
# 50605                                                NaN
# 50606                                                NaN
# 50607                                                NaN
# 50608                                                NaN
# 50609                                                NaN
# 50610                                                NaN
# 50611                                                NaN
# 50612                                                NaN
# 50613                                                NaN
# 50614                                                NaN
# 50615                                                NaN
# 50616                                                NaN
# 50618                                                NaN
# 50620                      http://www.aeroclubilgrifo.it
# 50621                                                NaN
# 50622                           http://www.akdubrava.net
# 50623                              http://www.agusta.ru/
# 50624                                                NaN
# 50625                                                NaN
# 50626                                                NaN
# 50627                                                NaN
# 50628                                                NaN
# 50629                                                NaN
# 50630                                                NaN
#
#                                           wikipedia_link  \
# 0      http://en.wikipedia.org/wiki/London_Heathrow_A...
# 1      http://en.wikipedia.org/wiki/Los_Angeles_Inter...
# 2      http://en.wikipedia.org/wiki/O'Hare_Internatio...
# 3      http://en.wikipedia.org/wiki/John_F._Kennedy_I...
# 4      http://en.wikipedia.org/wiki/Hartsfield-Jackso...
# 5      http://en.wikipedia.org/wiki/Charles_de_Gaulle...
# 6      http://en.wikipedia.org/wiki/San_Francisco_Int...
# 7      http://en.wikipedia.org/wiki/Amsterdam_Schipho...
# 8         http://en.wikipedia.org/wiki/Frankfurt_Airport
# 9      http://en.wikipedia.org/wiki/Newark_Liberty_In...
# 10     http://en.wikipedia.org/wiki/McCarran_Internat...
# 11     http://en.wikipedia.org/wiki/Dallas-Fort_Worth...
# 12     http://en.wikipedia.org/wiki/Orlando_Internati...
# 13     http://en.wikipedia.org/wiki/Denver_Internatio...
# 14     http://en.wikipedia.org/wiki/Miami_Internation...
# 15     http://en.wikipedia.org/wiki/Washington_Dulles...
# 16        http://en.wikipedia.org/wiki/LaGuardia_Airport
# 17     http://en.wikipedia.org/wiki/Phoenix_Sky_Harbo...
# 18     http://en.wikipedia.org/wiki/London_Gatwick_Ai...
# 19     http://en.wikipedia.org/wiki/Seattle-Tacoma_In...
# 20     http://en.wikipedia.org/wiki/Logan_Internation...
# 21     http://en.wikipedia.org/wiki/Philadelphia_Inte...
# 22     http://en.wikipedia.org/wiki/Toronto_Pearson_I...
# 23     http://en.wikipedia.org/wiki/Ronald_Reagan_Was...
# 24     http://en.wikipedia.org/wiki/George_Bush_Inter...
# 25     http://en.wikipedia.org/wiki/Charlotte/Douglas...
# 26     http://en.wikipedia.org/wiki/Detroit_Metropoli...
# 27     http://en.wikipedia.org/wiki/Munich_Internatio...
# 28     http://en.wikipedia.org/wiki/Minneapolis-Saint...
# 29     http://en.wikipedia.org/wiki/Leonardo_da_Vinci...
# ...                                                  ...
# 50599                                                NaN
# 50600                                                NaN
# 50601                                                NaN
# 50602     https://en.wikipedia.org/wiki/Zhigansk_Airport
# 50603  http://en.wikipedia.org/wiki/Zhongwei_Shapotou...
# 50604                                                NaN
# 50605                                                NaN
# 50606                                                NaN
# 50607    https://en.wikipedia.org/wiki/Ozerne_(air_base)
# 50608                                                NaN
# 50609                                                NaN
# 50610                                                NaN
# 50611                                                NaN
# 50612                                                NaN
# 50613                                                NaN
# 50614                                                NaN
# 50615                                                NaN
# 50616                                                NaN
# 50618                                                NaN
# 50620                                                NaN
# 50621  http://en.wikipedia.org/wiki/Zunyi_Xinzhou_Air...
# 50622                                                NaN
# 50623                                                NaN
# 50624                                                NaN
# 50625                                                NaN
# 50626                                                NaN
# 50627  https://en.wikipedia.org/wiki/Zyryanka_West_Ai...
# 50628                                                NaN
# 50629  https://en.wikipedia.org/wiki/%C3%9E%C3%B3rsh%...
# 50630                                                NaN
#
#                                                 keywords    score  \
# 0                                           LON, Londres  1251675
# 1                                                    NaN  1335475
# 2                                     CHI, Orchard Place  1503175
# 3                Manhattan, New York City, NYC, Idlewild  1052075
# 4                                                    NaN  2002475
# 5      PAR, Aéroport Roissy-Charles de Gaulle, Roissy...  1127475
# 6                                               QSF, QBA  1112475
# 7                                                    NaN  1093275
# 8                              EDAF, Rhein-Main Air Base  1144675
# 9                          Manhattan, New York City, NYC  1064475
# 10                                                   NaN  1068475
# 11                                                   QDF  1203175
# 12                             Disney World,Epcot Center  1044075
# 13                                             DVX, KVDX  1103275
# 14                                    MFW, South Florida  1073075
# 15                                                   WAS  1023875
# 16     Manhattan, New York City, NYC, Glenn H. Curtis...  1030575
# 17                                                   NaN  1060875
# 18                               LON, Crawley, Charlwood  1049275
# 19                                                   NaN  1038675
# 20     General Edward Lawrence Logan International Ai...  1035875
# 21                                                   NaN  1031075
# 22            YTO, Toronto International Airport, Malton  1040275
# 23                                                   WAS  1016175
# 24                                                   QHO  1055675
# 25                                                   NaN  1028075
# 26                            DTT, Detroit Metro Airport  1079375
# 27     Franz Josef Strauss International Airport, Flu...  1026675
# 28                                                   NaN  1085275
# 29        ROM, Rome Fiumicino Airport, Fiumicino Airport  1031875
# ...                                                  ...      ...
# 50599       Emba Air Base, Аэродром Карась,Аэродром Эмба        0
# 50600      Emba Air Base, Аэродром Карась, Аэродром Эмба        0
# 50601                                                NaN        0
# 50602                             УЕЖЖ, Аэропорт Жиганск        0
# 50603                                                NaN        0
# 50604  Dzhusaly Airport, Аэропорт Жосалы, Аэропорт Дж...        0
# 50605  Zholtyye Vody Airstrip, ЗПС Жовті Води, ВПП Жё...        0
# 50606                ЗПС Володимирівка, ВПП Владимировка        0
# 50607  Zhitomyr Ozernoye, Oziernoye, Ozernoe, Ozernoy...        0
# 50608                                                NaN        0
# 50609                                 Аэродром Зимовники        0
# 50610                                                NaN        0
# 50611                                                NaN        0
# 50612                               Аэродром Капустин Яр        0
# 50613                                                NaN        0
# 50614                                  Аэродром Пальмира        0
# 50615                                                NaN        0
# 50616                                                NaN        0
# 50618                                                NaN        0
# 50620                                                NaN        0
# 50621                                                NaN        0
# 50622                                                NaN        0
# 50623                                  Вертодром Пушкино        0
# 50624                                                NaN        0
# 50625                                                NaN        0
# 50626                                             EH0029        0
# 50627                           ZCQ6, Зырянка (Западный)        0
# 50628                                                NaN        0
# 50629                                                THO        0
# 50630                                                NaN        0
#
#                     last_updated
# 0      2016-02-09T10:54:31+00:00
# 1      2010-01-23T11:27:55+00:00
# 2      2014-08-19T18:55:27+00:00
# 3      2010-01-23T11:27:54+00:00
# 4      2008-06-13T14:30:04+00:00
# 5      2010-01-05T18:17:43+00:00
# 6      2008-06-13T14:30:04+00:00
# 7      2011-10-05T23:26:15+00:00
# 8      2016-09-15T03:34:21+00:00
# 9      2008-06-13T14:30:04+00:00
# 10     2010-07-05T16:48:39+00:00
# 11     2008-06-13T14:30:04+00:00
# 12     2008-06-13T14:30:04+00:00
# 13     2015-11-13T09:28:42+00:00
# 14     2008-06-13T14:30:04+00:00
# 15     2010-01-23T11:27:53+00:00
# 16     2010-01-23T11:27:55+00:00
# 17     2008-06-13T14:30:04+00:00
# 18     2009-01-30T17:53:54+00:00
# 19     2008-06-13T14:30:04+00:00
# 20     2010-01-23T11:27:48+00:00
# 21     2008-06-13T14:30:04+00:00
# 22     2009-10-15T13:44:39+00:00
# 23     2016-12-13T09:13:00+00:00
# 24     2008-06-13T14:30:04+00:00
# 25     2009-01-30T14:52:52+00:00
# 26     2008-06-13T14:30:04+00:00
# 27     2015-10-17T03:56:24+00:00
# 28     2009-12-17T08:53:11+00:00
# 29     2016-10-08T00:37:02+00:00
# ...                          ...
# 50599  2009-04-24T13:54:46+00:00
# 50600  2009-04-24T13:54:54+00:00
# 50601  2016-08-06T20:22:46+00:00
# 50602  2015-09-20T23:58:06+00:00
# 50603  2013-04-10T00:28:33+00:00
# 50604  2009-04-24T13:34:01+00:00
# 50605  2010-03-27T18:04:32+00:00
# 50606  2010-03-27T18:11:37+00:00
# 50607  2017-02-18T21:11:10+00:00
# 50608  2012-12-15T23:37:53+00:00
# 50609  2009-08-17T10:56:36+00:00
# 50610  2016-07-26T00:52:39+00:00
# 50611  2009-03-27T18:08:04+00:00
# 50612  2010-01-09T12:30:12+00:00
# 50613  2016-07-10T05:35:40+00:00
# 50614  2009-11-18T14:53:00+00:00
# 50615  2016-06-25T00:38:37+00:00
# 50616  2012-10-21T18:35:45+00:00
# 50618  2009-08-17T13:52:57+00:00
# 50620  2017-01-03T03:03:17+00:00
# 50621  2013-03-30T12:14:29+00:00
# 50622  2015-11-02T23:33:02+00:00
# 50623  2010-02-25T11:06:38+00:00
# 50624  2009-03-23T20:54:13+00:00
# 50625  2009-03-23T20:54:37+00:00
# 50626  2009-03-21T16:38:26+00:00
# 50627  2015-09-23T00:19:01+00:00
# 50628  2016-05-31T03:11:45+00:00
# 50629  2015-08-20T20:43:01+00:00
# 50630  2015-10-20T12:54:39+00:00
#
# [39368 rows x 20 columns]

# %% [markdown]
# - Subsetting (querying but return dataframe not just indices)

# %%
gb = df.groupby('type')

# %%
gb.all()
# Out:
#                continent elevation_ft gps_code home_link iata_code    id  \
# type
# balloonport         True         True     True      True      True  True
# closed              True        False     True      True      True  True
# heliport            True        False     True      True      True  True
# large_airport       True         True     True      True      True  True
# medium_airport      True        False     True      True      True  True
# seaplane_base       True        False     True      True      True  True
# small_airport       True        False     True      True      True  True
#
#                ident iso_country iso_region keywords last_updated  \
# type
# balloonport     True        True       True     True         True
# closed          True        True       True     True         True
# heliport        True        True       True     True         True
# large_airport   True        True       True     True         True
# medium_airport  True        True       True     True         True
# seaplane_base   True        True       True     True         True
# small_airport   True        True       True     True         True
#
#                latitude_deg local_code longitude_deg municipality  name  \
# type
# balloonport            True       True          True         True  True
# closed                False       True         False         True  True
# heliport               True       True          True         True  True
# large_airport         False       True         False         True  True
# medium_airport         True       True         False         True  True
# seaplane_base          True       True          True         True  True
# small_airport          True       True          True         True  True
#
#                scheduled_service  score wikipedia_link
# type
# balloonport                False  False           True
# closed                     False  False           True
# heliport                   False  False           True
# large_airport              False  False           True
# medium_airport             False  False           True
# seaplane_base              False  False           True
# small_airport              False  False           True

# %%
small = df[df.type=='small_airport']
medium = df[df.type=='medium_airport']
large = df[df.type=='large_airport']

# %%
len(small)
# Out:
# 32875

# %%
len(medium)
# Out:
# 4530

# %%
len(large)
# Out:
# 574

# %% [markdown]
# - spatial join - airports by countries

# %%
countries_shp = ps.pdio.read_files("data/airports/ne_10m_admin_0_countries/ne_10m_admin_0_countries.shp")

# %% [markdown]
# - derived features - point sequence to line for the routes
# - spatial join - does route pass through a country
# - crs: contextily example,
# - knn analysis - find most isolated airport
# - voronoi - whats my closest airport
# - dissolve - dissovle boundaries in europe

# %% [markdown]
# ## Vignette: House Prices

# %%
df = pd.read_csv('data/sandiego/listings.csv')
len(df)
# Out:
# 6608

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'access', 'interaction', 'house_rules',
#        'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url',
#        'host_id', 'host_url', 'host_name', 'host_since', 'host_location',
#        'host_about', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#        'host_picture_url', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#        'price', 'weekly_price', 'monthly_price', 'security_deposit',
#        'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'license', 'jurisdiction_names', 'instant_bookable',
#        'cancellation_policy', 'require_guest_profile_picture',
#        'require_guest_phone_verification', 'calculated_host_listings_count',
#        'reviews_per_month'],
#       dtype='object')

# %% [markdown]
# - keyword table join (census)
# (keyword comes from spatial join with polygon shown below)
#
# - groupby: avg house price by census polygon
# - buffer: deriving dummies for houses within x of an amenity
# - spatial join: create keyword that we use for the table
# - raster/clip with shape: elevation or pollution by tract, or by house, or  noise
# - voronoi - what's my closest coffee shop
#
# - Sets: union, intersection, difference: point out that these are really implied by the buffer used to define regimes (intersection dummy = 1, difference dummy=0)
#
# message is, if you have the column in the table use it, but many cases you do not have the column and need to go the spatial join route

# %% [markdown]
# ---
#
# <a rel="license" href="http://creativecommons.org/licenses/by-nc-nd/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-nd/4.0/88x31.png" /></a><br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc-nd/4.0/">Creative Commons Attribution-NonCommercial-NoDerivatives 4.0 International License</a>.
