# %% [markdown]
# # Wisconsin
#
# ## Issue from BEA Income Data:
#
# > Shawano, WI and Menominee, WI are combined as Shawano (incl. Menominee), WI for the years prior to 1989.
#
#
# ### Approach
#
# Combine Shawano and Menominee into one record.

# %%
import pandas
import geopandas
# %matplotlib inline

# %%
csv = pandas.read_csv('55.csv')

# %%
csv.head()
# Out:
#    Unnamed: 0   GeoFIPS    GeoName  Region TableName  LineCode  \
# 0        9276   "55000"  Wisconsin       3    CAINC1         1
# 1        9277   "55000"  Wisconsin       3    CAINC1         2
# 2        9278   "55000"  Wisconsin       3    CAINC1         3
# 3        9279   "55001"  Adams, WI       3    CAINC1         1
# 4        9280   "55001"  Adams, WI       3    CAINC1         2
#
#   IndustryClassification                              Description  \
# 0                    ...   Personal income (thousands of dollars)
# 1                    ...                  Population (persons) 1/
# 2                    ...  Per capita personal income (dollars) 2/
# 3                    ...   Personal income (thousands of dollars)
# 4                    ...                  Population (persons) 1/
#
#                    Unit      1969  ...       2008       2009       2010  \
# 0  Thousands of dollars  16424603  ...  219514508  215913287  221895293
# 1     Number of persons   4378000  ...    5640996    5669264    5690403
# 2               Dollars      3752  ...      38914      38085      38995
# 3  Thousands of dollars     22995  ...     584851     598851     610958
# 4     Number of persons      8875  ...      21101      20930      20886
#
#         2011       2012       2013       2014       2015       2016       2017
# 0  234574850  245700352  247127445  257572422  268237980  273787486  283635828
# 1    5705812    5721075    5736673    5751272    5759744    5772917    5795483
# 2      41112      42947      43079      44785      46571      47426      48941
# 3     647126     672207     677315     690438     717115     723620     753940
# 4      20778      20426      20419      20135      20032      19997      19973
#
# [5 rows x 58 columns]

# %%
csv[csv.GeoName.str.startswith('Shawano')]
# Out:
#      Unnamed: 0   GeoFIPS                            GeoName  Region  \
# 177        9453   "55115"                       Shawano, WI*       3
# 178        9454   "55115"                       Shawano, WI*       3
# 179        9455   "55115"                       Shawano, WI*       3
# 219        9495   "55901"  Shawano (includes Menominee), WI*       3
# 220        9496   "55901"  Shawano (includes Menominee), WI*       3
# 221        9497   "55901"  Shawano (includes Menominee), WI*       3
#
#     TableName  LineCode IndustryClassification  \
# 177    CAINC1         1                    ...
# 178    CAINC1         2                    ...
# 179    CAINC1         3                    ...
# 219    CAINC1         1                    ...
# 220    CAINC1         2                    ...
# 221    CAINC1         3                    ...
#
#                                  Description                  Unit   1969  \
# 177   Personal income (thousands of dollars)  Thousands of dollars   (NA)
# 178                  Population (persons) 1/     Number of persons   (NA)
# 179  Per capita personal income (dollars) 2/               Dollars   (NA)
# 219   Personal income (thousands of dollars)  Thousands of dollars  87148
# 220                  Population (persons) 1/     Number of persons  37033
# 221  Per capita personal income (dollars) 2/               Dollars   2353
#
#      ...     2008     2009     2010     2011     2012     2013     2014  \
# 177  ...  1321825  1293779  1354850  1418767  1460468  1486023  1547953
# 178  ...    41894    41889    41937    41663    41504    41409    41344
# 179  ...    31552    30886    32307    34053    35189    35886    37441
# 219  ...     (NA)     (NA)     (NA)     (NA)     (NA)     (NA)     (NA)
# 220  ...     (NA)     (NA)     (NA)     (NA)     (NA)     (NA)     (NA)
# 221  ...     (NA)     (NA)     (NA)     (NA)     (NA)     (NA)     (NA)
#
#         2015     2016     2017
# 177  1577052  1598211  1652000
# 178    41053    40941    40935
# 179    38415    39037    40357
# 219     (NA)     (NA)     (NA)
# 220     (NA)     (NA)     (NA)
# 221     (NA)     (NA)     (NA)
#
# [6 rows x 58 columns]

# %%
csv[csv.GeoName.str.startswith('Menominee')]
# Out:
#      Unnamed: 0   GeoFIPS         GeoName  Region TableName  LineCode  \
# 120        9396   "55078"  Menominee, WI*       3    CAINC1         1
# 121        9397   "55078"  Menominee, WI*       3    CAINC1         2
# 122        9398   "55078"  Menominee, WI*       3    CAINC1         3
#
#     IndustryClassification                              Description  \
# 120                    ...   Personal income (thousands of dollars)
# 121                    ...                  Population (persons) 1/
# 122                    ...  Per capita personal income (dollars) 2/
#
#                      Unit  1969  ...   2008    2009    2010    2011    2012  \
# 120  Thousands of dollars  (NA)  ...  94487  104406  108166  110847  115973
# 121     Number of persons  (NA)  ...   4214    4191    4268    4369    4358
# 122               Dollars  (NA)  ...  22422   24912   25343   25371   26612
#
#        2013    2014    2015    2016    2017
# 120  120709  122552  132578  130431  132733
# 121    4367    4491    4510    4537    4615
# 122   27641   27288   29396   28748   28761
#
# [3 rows x 58 columns]

# %%
csv = csv.replace('(NA)', 0)

# %%
menominee = csv.iloc[[120, 121, 122]]
shawano = csv.iloc[[177, 178, 179]]
combined = csv.iloc[[219, 220, 221]]

# %%
years = [str(y) for y in range(1989, 2018)]

# %%
menominee[years] = menominee[years].astype(int)
shawano[years] = shawano[years].astype(int)
combined[years] = combined[years].astype(int)
# Out:
# /usr/local/anaconda3/envs/gdsbook-jbupdate/lib/python3.8/site-packages/pandas/core/frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
cindex = [ combined.columns.values.tolist().index(y) for y in years]

for c,y in zip(cindex,years):
    #print(menominee[y].dtype)
    #print(shawano[y].dtype)
    #print(combined[y].dtype)
    combined.iloc[0,c] = menominee.iloc[0,c] + shawano.iloc[0,c]
    combined.iloc[1,c] = menominee.iloc[1,c] + shawano.iloc[1,c]
    combined.iloc[2,c] = int(combined.iloc[0,c]*1000/ combined.iloc[1,c])
    csv.iloc[219,c] = combined.iloc[0,c]
    csv.iloc[220,c] = combined.iloc[1,c]
    csv.iloc[221,c] = combined.iloc[2,c]
# Out:
# /usr/local/anaconda3/envs/gdsbook-jbupdate/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
combined
# Out:
#      Unnamed: 0   GeoFIPS                            GeoName  Region  \
# 219        9495   "55901"  Shawano (includes Menominee), WI*       3
# 220        9496   "55901"  Shawano (includes Menominee), WI*       3
# 221        9497   "55901"  Shawano (includes Menominee), WI*       3
#
#     TableName  LineCode IndustryClassification  \
# 219    CAINC1         1                    ...
# 220    CAINC1         2                    ...
# 221    CAINC1         3                    ...
#
#                                  Description                  Unit   1969  \
# 219   Personal income (thousands of dollars)  Thousands of dollars  87148
# 220                  Population (persons) 1/     Number of persons  37033
# 221  Per capita personal income (dollars) 2/               Dollars   2353
#
#      ...     2008     2009     2010     2011     2012     2013     2014  \
# 219  ...  1416312  1398185  1463016  1529614  1576441  1606732  1670505
# 220  ...    46108    46080    46205    46032    45862    45776    45835
# 221  ...    30717    30342    31663    33229    34373    35099    36446
#
#         2015     2016     2017
# 219  1709630  1728642  1784733
# 220    45563    45478    45550
# 221    37522    38010    39181
#
# [3 rows x 58 columns]

# %%
csv.iloc[[219,220,221]]
# Out:
#      Unnamed: 0   GeoFIPS                            GeoName  Region  \
# 219        9495   "55901"  Shawano (includes Menominee), WI*       3
# 220        9496   "55901"  Shawano (includes Menominee), WI*       3
# 221        9497   "55901"  Shawano (includes Menominee), WI*       3
#
#     TableName  LineCode IndustryClassification  \
# 219    CAINC1         1                    ...
# 220    CAINC1         2                    ...
# 221    CAINC1         3                    ...
#
#                                  Description                  Unit   1969  \
# 219   Personal income (thousands of dollars)  Thousands of dollars  87148
# 220                  Population (persons) 1/     Number of persons  37033
# 221  Per capita personal income (dollars) 2/               Dollars   2353
#
#      ...     2008     2009     2010     2011     2012     2013     2014  \
# 219  ...  1416312  1398185  1463016  1529614  1576441  1606732  1670505
# 220  ...    46108    46080    46205    46032    45862    45776    45835
# 221  ...    30717    30342    31663    33229    34373    35099    36446
#
#         2015     2016     2017
# 219  1709630  1728642  1784733
# 220    45563    45478    45550
# 221    37522    38010    39181
#
# [3 rows x 58 columns]

# %% [markdown]
# ## Drop shawano and menomiee from csv

# %%
drop_ids = [120, 121, 122, 177, 178, 179]
csv = csv.drop(drop_ids)

# %%
years = [str(y) for y in range(1969, 2018)]
csv[years] = csv[years].astype(int)

# %%
for year in range(1969,2018):
    print(csv[str(year)].dtype)
# Out:
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64

# %% [markdown]
# ## Dissolve shawano and menominee geometries in gdf
#
# dissolve
# and assign geofips

# %%
gdf = geopandas.read_file("tl_2019_us_county.shp")

# %%
wisconsin_gdf = gdf[gdf.STATEFP=="55"]

# %%
wisconsin_gdf.plot()
# Out:
# <AxesSubplot:>

# %%
wisconsin_gdf[wisconsin_gdf.NAME=='Shawano']
# Out:
#      STATEFP COUNTYFP  COUNTYNS  GEOID     NAME        NAMELSAD LSAD CLASSFP  \
# 1915      55      115  01581117  55115  Shawano  Shawano County   06      H1
#
#       MTFCC CSAFP CBSAFP METDIVFP FUNCSTAT       ALAND    AWATER     INTPTLAT  \
# 1915  G4020   267  43020     None        A  2313441748  41883060  +44.7896407
#
#           INTPTLON                                           geometry
# 1915  -088.7558134  POLYGON ((-89.22401 44.85627, -89.22401 44.856...

# %%
wisconsin_gdf[wisconsin_gdf.NAME=='Menominee']
# Out:
#      STATEFP COUNTYFP  COUNTYNS  GEOID       NAME          NAMELSAD LSAD  \
# 3133      55      078  01581099  55078  Menominee  Menominee County   06
#
#      CLASSFP  MTFCC CSAFP CBSAFP METDIVFP FUNCSTAT      ALAND    AWATER  \
# 3133      H1  G4020   267  43020     None        A  926217566  19022479
#
#          INTPTLAT      INTPTLON  \
# 3133  +44.9913041  -088.6692512
#
#                                                geometry
# 3133  POLYGON ((-88.98246 45.11800, -88.98218 45.118...

# %%
combined = wisconsin_gdf[wisconsin_gdf.COUNTYFP.isin(['115', '078'])].dissolve(by='STATEFP')

# %%
combined.plot()
# Out:
# <AxesSubplot:>

# %%
combined.head()
# Out:
#                                                   geometry COUNTYFP  COUNTYNS  \
# STATEFP
# 55       POLYGON ((-89.22401 44.85627, -89.22401 44.856...      115  01581117
#
#          GEOID     NAME        NAMELSAD LSAD CLASSFP  MTFCC CSAFP CBSAFP  \
# STATEFP
# 55       55115  Shawano  Shawano County   06      H1  G4020   267  43020
#
#         METDIVFP FUNCSTAT       ALAND    AWATER     INTPTLAT      INTPTLON
# STATEFP
# 55          None        A  2313441748  41883060  +44.7896407  -088.7558134

# %%
combined['NAME'] = "Shawano+Menominee"
combined['NAMELSAD'] = "Shawano+Menominee Counties"

# %%
combined.head()
# Out:
#                                                   geometry COUNTYFP  COUNTYNS  \
# STATEFP
# 55       POLYGON ((-89.22401 44.85627, -89.22401 44.856...      115  01581117
#
#          GEOID               NAME                    NAMELSAD LSAD CLASSFP  \
# STATEFP
# 55       55115  Shawano+Menominee  Shawano+Menominee Counties   06      H1
#
#          MTFCC CSAFP CBSAFP METDIVFP FUNCSTAT       ALAND    AWATER  \
# STATEFP
# 55       G4020   267  43020     None        A  2313441748  41883060
#
#             INTPTLAT      INTPTLON
# STATEFP
# 55       +44.7896407  -088.7558134

# %%
combined['GEOID'] = '55901'

# %%
combined.head()
# Out:
#                                                   geometry COUNTYFP  COUNTYNS  \
# STATEFP
# 55       POLYGON ((-89.22401 44.85627, -89.22401 44.856...      115  01581117
#
#          GEOID               NAME                    NAMELSAD LSAD CLASSFP  \
# STATEFP
# 55       55901  Shawano+Menominee  Shawano+Menominee Counties   06      H1
#
#          MTFCC CSAFP CBSAFP METDIVFP FUNCSTAT       ALAND    AWATER  \
# STATEFP
# 55       G4020   267  43020     None        A  2313441748  41883060
#
#             INTPTLAT      INTPTLON
# STATEFP
# 55       +44.7896407  -088.7558134

# %%
wisc0 = wisconsin_gdf[~wisconsin_gdf.COUNTYFP.isin(['115', '078'])]

# %%
wisc0.plot()
# Out:
# <AxesSubplot:>

# %%
wisc1 = pandas.concat([wisc0, combined])

# %%
wisc1.plot()
# Out:
# <AxesSubplot:>

# %%
wisc1.head()
# Out:
#     STATEFP COUNTYFP  COUNTYNS  GEOID       NAME          NAMELSAD LSAD  \
# 16       55      111  01581115  55111       Sauk       Sauk County   06
# 145      55      093  01581107  55093     Pierce     Pierce County   06
# 155      55      063  01581091  55063  La Crosse  La Crosse County   06
# 161      55      033  01581076  55033       Dunn       Dunn County   06
# 171      55      053  01581086  55053    Jackson    Jackson County   06
#
#     CLASSFP  MTFCC CSAFP CBSAFP METDIVFP FUNCSTAT       ALAND    AWATER  \
# 16       H1  G4020   357  12660     None        A  2153685971  45692999
# 145      H1  G4020   378  33460     None        A  1486700515  48452318
# 155      H1  G4020  None  29100     None        A  1170076618  73110198
# 161      H1  G4020   232  32860     None        A  2201905281  35570217
# 171      H1  G4020  None   None     None        A  2558687761  32538303
#
#         INTPTLAT      INTPTLON  \
# 16   +43.4280010  -089.9433184
# 145  +44.7253365  -092.4262793
# 155  +43.9082222  -091.1117584
# 161  +44.9477513  -091.8976451
# 171  +44.3245897  -090.7995104
#
#                                               geometry
# 16   POLYGON ((-90.19196 43.55500, -90.19676 43.554...
# 145  POLYGON ((-92.69454 44.68874, -92.69466 44.688...
# 155  POLYGON ((-91.34774 43.91196, -91.34874 43.912...
# 161  POLYGON ((-92.13538 44.94481, -92.13538 44.944...
# 171  POLYGON ((-91.16601 44.33510, -91.16600 44.335...

# %%
wisc1.shape
# Out:
# (71, 18)

# %%
wisconsin_gdf.shape
# Out:
# (72, 18)

# %% [markdown]
# ## Merge gdf and csv

# %%
csv['GeoFIPS'] = [fip.strip().replace("\"", "") for fip in csv.GeoFIPS]

# %%
wisc1.head()
# Out:
#     STATEFP COUNTYFP  COUNTYNS  GEOID       NAME          NAMELSAD LSAD  \
# 16       55      111  01581115  55111       Sauk       Sauk County   06
# 145      55      093  01581107  55093     Pierce     Pierce County   06
# 155      55      063  01581091  55063  La Crosse  La Crosse County   06
# 161      55      033  01581076  55033       Dunn       Dunn County   06
# 171      55      053  01581086  55053    Jackson    Jackson County   06
#
#     CLASSFP  MTFCC CSAFP CBSAFP METDIVFP FUNCSTAT       ALAND    AWATER  \
# 16       H1  G4020   357  12660     None        A  2153685971  45692999
# 145      H1  G4020   378  33460     None        A  1486700515  48452318
# 155      H1  G4020  None  29100     None        A  1170076618  73110198
# 161      H1  G4020   232  32860     None        A  2201905281  35570217
# 171      H1  G4020  None   None     None        A  2558687761  32538303
#
#         INTPTLAT      INTPTLON  \
# 16   +43.4280010  -089.9433184
# 145  +44.7253365  -092.4262793
# 155  +43.9082222  -091.1117584
# 161  +44.9477513  -091.8976451
# 171  +44.3245897  -090.7995104
#
#                                               geometry
# 16   POLYGON ((-90.19196 43.55500, -90.19676 43.554...
# 145  POLYGON ((-92.69454 44.68874, -92.69466 44.688...
# 155  POLYGON ((-91.34774 43.91196, -91.34874 43.912...
# 161  POLYGON ((-92.13538 44.94481, -92.13538 44.944...
# 171  POLYGON ((-91.16601 44.33510, -91.16600 44.335...

# %%
wisc1.STATEFP='55'

# %%
data = csv

# %%
data.head()
# Out:
#    Unnamed: 0 GeoFIPS    GeoName  Region TableName  LineCode  \
# 0        9276   55000  Wisconsin       3    CAINC1         1
# 1        9277   55000  Wisconsin       3    CAINC1         2
# 2        9278   55000  Wisconsin       3    CAINC1         3
# 3        9279   55001  Adams, WI       3    CAINC1         1
# 4        9280   55001  Adams, WI       3    CAINC1         2
#
#   IndustryClassification                              Description  \
# 0                    ...   Personal income (thousands of dollars)
# 1                    ...                  Population (persons) 1/
# 2                    ...  Per capita personal income (dollars) 2/
# 3                    ...   Personal income (thousands of dollars)
# 4                    ...                  Population (persons) 1/
#
#                    Unit      1969  ...       2008       2009       2010  \
# 0  Thousands of dollars  16424603  ...  219514508  215913287  221895293
# 1     Number of persons   4378000  ...    5640996    5669264    5690403
# 2               Dollars      3752  ...      38914      38085      38995
# 3  Thousands of dollars     22995  ...     584851     598851     610958
# 4     Number of persons      8875  ...      21101      20930      20886
#
#         2011       2012       2013       2014       2015       2016       2017
# 0  234574850  245700352  247127445  257572422  268237980  273787486  283635828
# 1    5705812    5721075    5736673    5751272    5759744    5772917    5795483
# 2      41112      42947      43079      44785      46571      47426      48941
# 3     647126     672207     677315     690438     717115     723620     753940
# 4      20778      20426      20419      20135      20032      19997      19973
#
# [5 rows x 58 columns]

# %%
data['GEOID'] = data.GeoFIPS

# %%
data.GEOID
# Out:
# 0      55000
# 1      55000
# 2      55000
# 3      55001
# 4      55001
#        ...
# 217    55141
# 218    55141
# 219    55901
# 220    55901
# 221    55901
# Name: GEOID, Length: 216, dtype: object

# %% [markdown]
# ## gdf records missing income values

# %%
#data = data[data.LineCode==3]
merged_gdf = wisc1.merge(data, on='GEOID')

# %%
set(wisc1.GEOID)
# Out:
# {'55001',
#  '55003',
#  '55005',
#  '55007',
#  '55009',
#  '55011',
#  '55013',
#  '55015',
#  '55017',
#  '55019',
#  '55021',
#  '55023',
#  '55025',
#  '55027',
#  '55029',
#  '55031',
#  '55033',
#  '55035',
#  '55037',
#  '55039',
#  '55041',
#  '55043',
#  '55045',
#  '55047',
#  '55049',
#  '55051',
#  '55053',
#  '55055',
#  '55057',
#  '55059',
#  '55061',
#  '55063',
#  '55065',
#  '55067',
#  '55069',
#  '55071',
#  '55073',
#  '55075',
#  '55077',
#  '55079',
#  '55081',
#  '55083',
#  '55085',
#  '55087',
#  '55089',
#  '55091',
#  '55093',
#  '55095',
#  '55097',
#  '55099',
#  '55101',
#  '55103',
#  '55105',
#  '55107',
#  '55109',
#  '55111',
#  '55113',
#  '55117',
#  '55119',
#  '55121',
#  '55123',
#  '55125',
#  '55127',
#  '55129',
#  '55131',
#  '55133',
#  '55135',
#  '55137',
#  '55139',
#  '55141',
#  '55901'}

# %%
merged_gdf.plot()
# Out:
# <AxesSubplot:>

# %%
merged_gdf.head()
# Out:
#   STATEFP COUNTYFP  COUNTYNS  GEOID    NAME       NAMELSAD LSAD CLASSFP  \
# 0      55      111  01581115  55111    Sauk    Sauk County   06      H1
# 1      55      111  01581115  55111    Sauk    Sauk County   06      H1
# 2      55      111  01581115  55111    Sauk    Sauk County   06      H1
# 3      55      093  01581107  55093  Pierce  Pierce County   06      H1
# 4      55      093  01581107  55093  Pierce  Pierce County   06      H1
#
#    MTFCC CSAFP  ...     2008     2009     2010     2011     2012     2013  \
# 0  G4020   357  ...  2162156  2130031  2247789  2365214  2495867  2553889
# 1  G4020   357  ...    61231    61562    62072    62272    62415    62818
# 2  G4020   357  ...    35311    34600    36213    37982    39988    40655
# 3  G4020   378  ...  1428373  1372977  1429277  1529395  1592435  1605327
# 4  G4020   378  ...    40758    40613    41065    40873    40705    40778
#
#       2014     2015     2016     2017
# 0  2688269  2800980  2832908  2933322
# 1    63005    63292    63604    63981
# 2    42668    44255    44540    45847
# 3  1706776  1785974  1801618  1870308
# 4    41003    41020    41428    41901
#
# [5 rows x 76 columns]

# %%
merged_gdf.shape[0]/3
# Out:
# 71.0

# %%
matched_names = set(merged_gdf.NAMELSAD)

# %%
matched_names
# Out:
# {'Adams County',
#  'Ashland County',
#  'Barron County',
#  'Bayfield County',
#  'Brown County',
#  'Buffalo County',
#  'Burnett County',
#  'Calumet County',
#  'Chippewa County',
#  'Clark County',
#  'Columbia County',
#  'Crawford County',
#  'Dane County',
#  'Dodge County',
#  'Door County',
#  'Douglas County',
#  'Dunn County',
#  'Eau Claire County',
#  'Florence County',
#  'Fond du Lac County',
#  'Forest County',
#  'Grant County',
#  'Green County',
#  'Green Lake County',
#  'Iowa County',
#  'Iron County',
#  'Jackson County',
#  'Jefferson County',
#  'Juneau County',
#  'Kenosha County',
#  'Kewaunee County',
#  'La Crosse County',
#  'Lafayette County',
#  'Langlade County',
#  'Lincoln County',
#  'Manitowoc County',
#  'Marathon County',
#  'Marinette County',
#  'Marquette County',
#  'Milwaukee County',
#  'Monroe County',
#  'Oconto County',
#  'Oneida County',
#  'Outagamie County',
#  'Ozaukee County',
#  'Pepin County',
#  'Pierce County',
#  'Polk County',
#  'Portage County',
#  'Price County',
#  'Racine County',
#  'Richland County',
#  'Rock County',
#  'Rusk County',
#  'Sauk County',
#  'Sawyer County',
#  'Shawano+Menominee Counties',
#  'Sheboygan County',
#  'St. Croix County',
#  'Taylor County',
#  'Trempealeau County',
#  'Vernon County',
#  'Vilas County',
#  'Walworth County',
#  'Washburn County',
#  'Washington County',
#  'Waukesha County',
#  'Waupaca County',
#  'Waushara County',
#  'Winnebago County',
#  'Wood County'}

# %%
missing_gdf = wisc1[~wisc1.GEOID.isin(merged_gdf.GEOID)]

# %%
missing_names = set(missing_gdf.NAMELSAD)

# %%
missing_names
# Out:
# set()

# %%
missing_gdf.head()
# Out:
# Empty GeoDataFrame
# Columns: [STATEFP, COUNTYFP, COUNTYNS, GEOID, NAME, NAMELSAD, LSAD, CLASSFP, MTFCC, CSAFP, CBSAFP, METDIVFP, FUNCSTAT, ALAND, AWATER, INTPTLAT, INTPTLON, geometry]
# Index: []

# %%
usva = geopandas.read_file('usva.shp')

# %%
us_no_wisc = usva[usva.STATEFP!='55']

# %%
us = pandas.concat([merged_gdf, us_no_wisc])

# %%
us.shape
# Out:
# (9237, 77)

# %%
9098/3
# Out:
# 3032.6666666666665

# %%
us_no_wisc.plot()
# Out:
# <AxesSubplot:>

# %%
us.plot()
# Out:
# <AxesSubplot:>

# %%
us.shape
# Out:
# (9237, 77)

# %%
9240/3
# Out:
# 3080.0

# %%
us.head()
# Out:
#   STATEFP COUNTYFP  COUNTYNS  GEOID    NAME       NAMELSAD LSAD CLASSFP  \
# 0      55      111  01581115  55111    Sauk    Sauk County   06      H1
# 1      55      111  01581115  55111    Sauk    Sauk County   06      H1
# 2      55      111  01581115  55111    Sauk    Sauk County   06      H1
# 3      55      093  01581107  55093  Pierce  Pierce County   06      H1
# 4      55      093  01581107  55093  Pierce  Pierce County   06      H1
#
#    MTFCC CSAFP  ...     2009     2010     2011     2012     2013     2014  \
# 0  G4020   357  ...  2130031  2247789  2365214  2495867  2553889  2688269
# 1  G4020   357  ...    61562    62072    62272    62415    62818    63005
# 2  G4020   357  ...    34600    36213    37982    39988    40655    42668
# 3  G4020   378  ...  1372977  1429277  1529395  1592435  1605327  1706776
# 4  G4020   378  ...    40613    41065    40873    40705    40778    41003
#
#       2015     2016     2017 index
# 0  2800980  2832908  2933322   NaN
# 1    63292    63604    63981   NaN
# 2    44255    44540    45847   NaN
# 3  1785974  1801618  1870308   NaN
# 4    41020    41428    41901   NaN
#
# [5 rows x 77 columns]

# %%
for y in range(1969, 2018):
    print(us[str(y)].dtype)
# Out:
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64

# %%
us.to_file('usincome.shp')
