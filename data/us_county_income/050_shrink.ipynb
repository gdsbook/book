# %%
import geopandas
import pandas

# %%
gdf = geopandas.read_file('usincome_final.shp')

# %%
gdf.head()
# Out:
#      1969    1970    1971    1972    1973    1974    1975    1976    1977  \
# 0  148926  154820  164182  177909  200349  208954  232188  250796  285130
# 1   38212   39021   39247   40037   40867   41030   42132   42114   42490
# 2    3897    3968    4183    4444    4902    5093    5511    5955    6711
# 3   91916  100258  106854  116383  132623  143709  155120  173709  198952
# 4   26277   26865   27818   28406   28683   28815   29272   29764   30474
#
#      1978  ...  LineCode  METDIVFP  MTFCC    NAME       NAMELSAD  Region  \
# 0  317742  ...         1      None  G4020    Sauk    Sauk County       3
# 1   42491  ...         2      None  G4020    Sauk    Sauk County       3
# 2    7478  ...         3      None  G4020    Sauk    Sauk County       3
# 3  221278  ...         1      None  G4020  Pierce  Pierce County       3
# 4   30450  ...         2      None  G4020  Pierce  Pierce County       3
#
#    STATEFP  TableName                  Unit  \
# 0       55     CAINC1  Thousands of dollars
# 1       55     CAINC1     Number of persons
# 2       55     CAINC1               Dollars
# 3       55     CAINC1  Thousands of dollars
# 4       55     CAINC1     Number of persons
#
#                                             geometry
# 0  POLYGON ((-90.191964 43.554996, -90.196759 43....
# 1  POLYGON ((-90.191964 43.554996, -90.196759 43....
# 2  POLYGON ((-90.191964 43.554996, -90.196759 43....
# 3  POLYGON ((-92.694542 44.68874, -92.694659 44.6...
# 4  POLYGON ((-92.694542 44.68874, -92.694659 44.6...
#
# [5 rows x 76 columns]

# %% [markdown]
# ## Shrinking file size
# We are duplicating the shapes three times (once for each attribute)
#
# Split out the attributes from the geometries, two different dataframes

# %%
uscountyincome = pandas.DataFrame(gdf.drop(columns='geometry'))

# %%
uscountyincome.to_csv('uscountyincome.csv')

# %%
gdf.head()
# Out:
#      1969    1970    1971    1972    1973    1974    1975    1976    1977  \
# 0  148926  154820  164182  177909  200349  208954  232188  250796  285130
# 1   38212   39021   39247   40037   40867   41030   42132   42114   42490
# 2    3897    3968    4183    4444    4902    5093    5511    5955    6711
# 3   91916  100258  106854  116383  132623  143709  155120  173709  198952
# 4   26277   26865   27818   28406   28683   28815   29272   29764   30474
#
#      1978  ...  LineCode  METDIVFP  MTFCC    NAME       NAMELSAD  Region  \
# 0  317742  ...         1      None  G4020    Sauk    Sauk County       3
# 1   42491  ...         2      None  G4020    Sauk    Sauk County       3
# 2    7478  ...         3      None  G4020    Sauk    Sauk County       3
# 3  221278  ...         1      None  G4020  Pierce  Pierce County       3
# 4   30450  ...         2      None  G4020  Pierce  Pierce County       3
#
#    STATEFP  TableName                  Unit  \
# 0       55     CAINC1  Thousands of dollars
# 1       55     CAINC1     Number of persons
# 2       55     CAINC1               Dollars
# 3       55     CAINC1  Thousands of dollars
# 4       55     CAINC1     Number of persons
#
#                                             geometry
# 0  POLYGON ((-90.191964 43.554996, -90.196759 43....
# 1  POLYGON ((-90.191964 43.554996, -90.196759 43....
# 2  POLYGON ((-90.191964 43.554996, -90.196759 43....
# 3  POLYGON ((-92.694542 44.68874, -92.694659 44.6...
# 4  POLYGON ((-92.694542 44.68874, -92.694659 44.6...
#
# [5 rows x 76 columns]

# %%
gdf = gdf[gdf.LineCode==3]

# %%
gdf.shape
# Out:
# (3077, 76)

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
gdf.plot(column='2017')

# %%
gdf.to_file("uscountypcincome.gpk", layer='pcincome', driver="GPKG")
